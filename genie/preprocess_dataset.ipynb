# %% [markdown]
# # Preprocess Dataset
# <br>
#
# > #### Gino Prasad
# > #### 09/11/2024
# <br>

# %%
import pandas as pd
import numpy as np
import os, glob

# %%
dataset_path = "/Users/ginoprasad/Job_Applications/web_crawler/dataset/COMPLETED_APPLICATIONS/broadcom_app_v1/dataset.txt"

# %%
with open(dataset_path) as infile:
    text = infile.read()

# %%
text.split('\n')[16::18]
# Out:
# ['Profile.how_did_you_hear',
#  'ignore',
#  'click',
#  'Profile.country',
#  'Profile.first_name',
#  'Profile.last_name',
#  'ignore',
#  'ignore',
#  'ignore',
#  'ignore',
#  'ignore',
#  'Profile.email',
#  'Profile.phone_type',
#  'ignore',
#  'Profile.phone_num',
#  'ignore',
#  'click',
#  'click_no',
#  'click_no',
#  'click_no',
#  'click_no',
#  'Profile.ethnicity',
#  'Profile.gender',
#  'Profile.click_not_veteran',
#  'click',
#  'Profile.language',
#  'ignore',
#  'ignore',
#  'ignore',
#  'Profile.full_name',
#  'ignore',
#  'current_month',
#  'current_day',
#  'current_year',
#  'ignore',
#  'ignore',
#  'ignore']

# %% [markdown]
# Profile.how_did_you_hear
# Profile.country
# Profile.first_name
# Profile.last_name
# ignore
# click (if button, click yes)
# click_no
# Profile.email
# Profile.phone_type
# Profile.phone_num
# Profile.ethnicity
# Profile.gender
# Profile.click_not_veteran
# Profile.language
# Profile.full_name
# current_month
# current_day
# current_year

# %%
dataset
# Out:
# '/Users/ginoprasad/Job_Applications/web_crawler/dataset/COMPLETED_APPLICATIONS/broadcom_application_v1.txt'
